# %%
import tensorflow as tf
import numpy as np
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import glob

# %%
img = glob.glob('E:/TF_project/learn/dataset/城市街景数据集/images/train/*/*.png')

# %%
len(img)
# Out:
# 2975

# %%
img[:5]
# Out:
# ['E:/TF_project/learn/dataset/城市街景数据集/images/train\\aachen\\aachen_000000_000019_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/train\\aachen\\aachen_000001_000019_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/train\\aachen\\aachen_000002_000019_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/train\\aachen\\aachen_000003_000019_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/train\\aachen\\aachen_000004_000019_leftImg8bit.png']

# %%
label = glob.glob('E:/TF_project/learn/dataset/城市街景数据集/train/*/*_gtFine_labelIds.png')

# %%
len(label)
# Out:
# 2975

# %%
label[:5]
# Out:
# ['E:/TF_project/learn/dataset/城市街景数据集/train\\aachen\\aachen_000000_000019_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/train\\aachen\\aachen_000001_000019_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/train\\aachen\\aachen_000002_000019_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/train\\aachen\\aachen_000003_000019_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/train\\aachen\\aachen_000004_000019_gtFine_labelIds.png']

# %%
img_test = glob.glob('E:/TF_project/learn/dataset/城市街景数据集/images/val/*/*.png')
label_test = glob.glob('E:/TF_project/learn/dataset/城市街景数据集/val/*/*_gtFine_labelIds.png')

# %%
len(img_test), len(label_test)
# Out:
# (500, 500)

# %%
img_test[:5]
# Out:
# ['E:/TF_project/learn/dataset/城市街景数据集/images/val\\frankfurt\\frankfurt_000000_000294_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/val\\frankfurt\\frankfurt_000000_000576_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/val\\frankfurt\\frankfurt_000000_001016_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/val\\frankfurt\\frankfurt_000000_001236_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/val\\frankfurt\\frankfurt_000000_001751_leftImg8bit.png']

# %%
label_test[:5]
# Out:
# ['E:/TF_project/learn/dataset/城市街景数据集/val\\frankfurt\\frankfurt_000000_000294_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/val\\frankfurt\\frankfurt_000000_000576_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/val\\frankfurt\\frankfurt_000000_001016_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/val\\frankfurt\\frankfurt_000000_001236_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/val\\frankfurt\\frankfurt_000000_001751_gtFine_labelIds.png']

# %%
import random
random.shuffle(img)
random.shuffle(label)

# %%
img[:3]
# Out:
# ['E:/TF_project/learn/dataset/城市街景数据集/images/train\\strasbourg\\strasbourg_000001_016481_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/train\\stuttgart\\stuttgart_000103_000019_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/train\\aachen\\aachen_000070_000019_leftImg8bit.png']

# %%
label[:3]
# Out:
# ['E:/TF_project/learn/dataset/城市街景数据集/train\\zurich\\zurich_000115_000019_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/train\\hamburg\\hamburg_000000_103075_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/train\\ulm\\ulm_000061_000019_gtFine_labelIds.png']

# %%
#index = np.random.permutation(len(img))

# %%
#img = np.array(img)[index]
#label = np.array(label)[index]

# %%
#img[:3]

# %%
#label[:3]

# %%
train_count = len(img)
test_count = len(img_test)
train_count, test_count
# Out:
# (2975, 500)

# %%
img[0].split('\\')[-1].split('_leftImg8bit.png')[0]
# Out:
# 'strasbourg_000001_016481'

# %%
#提取image与label的共同name数据
img_names = [x.split('\\')[-1].split('_leftImg8bit.png')[0] for x in img]

# %%
img_names[:3]
# Out:
# ['strasbourg_000001_016481', 'stuttgart_000103_000019', 'aachen_000070_000019']

# %%
label_names = [x.split('\\')[-1].split('_gtFine_labelIds.png')[0] for x in label]
label_names[:3]
# Out:
# ['zurich_000115_000019', 'hamburg_000000_103075', 'ulm_000061_000019']

# %%
labels_train = [label_train for label_train in label 
                if(label_train.split('\\')[-1].split('_gtFine_labelIds.png')[0] in img_names)]

# %%
labels_train[:3]
# Out:
# ['E:/TF_project/learn/dataset/城市街景数据集/train\\zurich\\zurich_000115_000019_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/train\\hamburg\\hamburg_000000_103075_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/train\\ulm\\ulm_000061_000019_gtFine_labelIds.png']

# %%
#排序
labels_train.sort(key=lambda x : x.split('\\')[-1].split('_gtFine_labelIds.png')[0])

# %%
img.sort( key=lambda x : x.split('\\')[-1].split('_leftImg8bit.png')[0] )

# %%
labels_train[:3]
# Out:
# ['E:/TF_project/learn/dataset/城市街景数据集/train\\aachen\\aachen_000000_000019_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/train\\aachen\\aachen_000001_000019_gtFine_labelIds.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/train\\aachen\\aachen_000002_000019_gtFine_labelIds.png']

# %%
img[:3]
# Out:
# ['E:/TF_project/learn/dataset/城市街景数据集/images/train\\aachen\\aachen_000000_000019_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/train\\aachen\\aachen_000001_000019_leftImg8bit.png',
#  'E:/TF_project/learn/dataset/城市街景数据集/images/train\\aachen\\aachen_000002_000019_leftImg8bit.png']

# %%
dataset_train = tf.data.Dataset.from_tensor_slices((img, labels_train))
dataset_train
# Out:
# <TensorSliceDataset shapes: ((), ()), types: (tf.string, tf.string)>

# %%
dataset_test = tf.data.Dataset.from_tensor_slices((img_test, label_test))

# %%
def read_png(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_png(img, channels=3)
    return img

# %%
def read_png_label(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_png(img, channels=1)
    return img

# %%
img_1 = read_png(img[0])
label_1 = read_png_label(labels_train[0])

# %%
img_1.shape,label_1.shape
# Out:
# (TensorShape([1024, 2048, 3]), TensorShape([1024, 2048, 1]))

# %% [markdown]
# # 数据增强

# %%
#图像与标注图同时
#1.随机翻转
#2.随即裁剪

# %%
caoncat_img = tf.concat([img_1, label_1], axis = -1)

# %%
caoncat_img.shape
# Out:
# TensorShape([1024, 2048, 4])

# %%
def crop_img(img, mask):
    caoncat_img = tf.concat([img, mask], axis = -1)
    caoncat_img = tf.image.resize(caoncat_img, (280, 280), 
                        method = tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    crop_img = tf.image.random_crop(caoncat_img, [256, 256, 4])
    return crop_img[ :, :, :3], crop_img[ :, :, 3:]

# %%
img_1, label_1 = crop_img(img_1, label_1)
img_1.shape, label_1.shape
# Out:
# (TensorShape([256, 256, 3]), TensorShape([256, 256, 1]))

# %%
plt.subplot(1,2,1)
plt.imshow(img_1.numpy())
plt.subplot(1,2,2)
plt.imshow(np.squeeze(label_1.numpy()))

# %%
def normal(img, mask):
    img = tf.cast(img, tf.float32)/127.5 - 1
    mask = tf.cast(mask, tf.int32)
    return img, mask

# %%
def load_image_train(img_path, mask_path):
    img = read_png(img_path)
    mask = read_png_label(mask_path)
    
    img, mask = crop_img(img, mask)
    if tf.random.uniform(()) > 0.5:
        img = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
        
    img, mask = normal(img, mask)
    return img, mask

# %%
def load_image_test(img_path, mask_path):
    img = read_png(img_path)
    mask = read_png_label(mask_path)
    
    img = tf.image.resize(img, (256, 256))
    mask = tf.image.resize(mask, (256, 256))
        
    img, mask = normal(img, mask)
    return img, mask

# %%
BATCH_SIZE = 2
BUFFER_SIZE = 300
step_per_epoch = train_count // BATCH_SIZE
val_step = test_count // BATCH_SIZE

# %%
auto = tf.data.experimental.AUTOTUNE

# %%
dataset_train = dataset_train.map(load_image_train, num_parallel_calls = auto)
dataset_test = dataset_test.map(load_image_test, num_parallel_calls = auto)

# %%
for i, m in dataset_train.take(1):
    plt.subplot(1,2,1)
    plt.imshow((i.numpy() + 1) / 2)
    plt.subplot(1,2,2)
    plt.imshow(np.squeeze(m.numpy()))

# %%
dataset_train = dataset_train.repeat().shuffle(BUFFER_SIZE).prefetch(auto)
dataset_train
# Out:
# <PrefetchDataset shapes: ((256, 256, 3), (256, 256, 1)), types: (tf.float32, tf.int32)>

# %%
dataset_train = dataset_train.cache().repeat().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).prefetch(auto)
dataset_test = dataset_test.cache().batch(BATCH_SIZE)

# %%
dataset_train
# Out:
# <PrefetchDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.int32)>

# %% [markdown]
# # 定义UNET模型

# %%
np.unique(label_1.numpy())
# Out:
# array([ 1,  4,  7,  8, 11, 17, 20, 21, 22, 23, 24, 25, 26, 33],
#       dtype=uint8)

# %%
def create_model():
    inputs = tf.keras.layers.Input(shape=(256, 256, 3))
    
    #下采样部分
    x = tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu')(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x) #256*256*64
    
    x1 = tf.keras.layers.MaxPooling2D()(x) #128*128*64
    
    x1 = tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu')(x1)
    x1 = tf.keras.layers.BatchNormalization()(x1) 
    x1 = tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu')(x1)
    x1 = tf.keras.layers.BatchNormalization()(x1) #128*128*128
    
    x2 = tf.keras.layers.MaxPooling2D()(x1) #64*64*128
    
    x2 = tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu')(x2)
    x2 = tf.keras.layers.BatchNormalization()(x2) 
    x2 = tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu')(x2)
    x2 = tf.keras.layers.BatchNormalization()(x2) #64*64*256
    
    x3 = tf.keras.layers.MaxPooling2D()(x2) #32*32*256
    
    x3 = tf.keras.layers.Conv2D(512, 3, padding='same', activation='relu')(x3)
    x3 = tf.keras.layers.BatchNormalization()(x3) 
    x3 = tf.keras.layers.Conv2D(512, 3, padding='same', activation='relu')(x3)
    x3 = tf.keras.layers.BatchNormalization()(x3) #32*32*512
    
    x4 = tf.keras.layers.MaxPooling2D()(x3) #16*16*512
    
    x4 = tf.keras.layers.Conv2D(1024, 3, padding='same', activation='relu')(x4)
    x4 = tf.keras.layers.BatchNormalization()(x4) 
    x4 = tf.keras.layers.Conv2D(1024, 3, padding='same', activation='relu')(x4)
    x4 = tf.keras.layers.BatchNormalization()(x4) #16*16*1024
    
    #上采样部分
    x5 = tf.keras.layers.Conv2DTranspose(512, 2, strides = 2,
                                         padding='same', activation='relu')(x4)
    x5 = tf.keras.layers.BatchNormalization()(x5) #32*32*512
    #跳阶合并
    x6 = tf.concat([x3, x5], axis = -1) #32*32*1024
    
    x6 = tf.keras.layers.Conv2D(512, 3, padding='same', activation='relu')(x6)
    x6 = tf.keras.layers.BatchNormalization()(x6) 
    x6 = tf.keras.layers.Conv2D(512, 3, padding='same', activation='relu')(x6)
    x6 = tf.keras.layers.BatchNormalization()(x6) #32*32*512
    
    x7 = tf.keras.layers.Conv2DTranspose(256, 2, strides = 2,
                                         padding='same', activation='relu')(x6)
    x7 = tf.keras.layers.BatchNormalization()(x7) #64*64*256
    x8 = tf.concat([x2, x7], axis = -1) #64*64*512
    
    x8 = tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu')(x8)
    x8 = tf.keras.layers.BatchNormalization()(x8) 
    x8 = tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu')(x8)
    x8 = tf.keras.layers.BatchNormalization()(x8) #64*64*256
    
    x9 = tf.keras.layers.Conv2DTranspose(128, 2, strides = 2,
                                         padding='same', activation='relu')(x8)
    x9 = tf.keras.layers.BatchNormalization()(x9) #128*128*128
    x10 = tf.concat([x1, x9], axis = -1) #128*128*256
    
    x10 = tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu')(x10)
    x10 = tf.keras.layers.BatchNormalization()(x10) 
    x10 = tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu')(x10)
    x10 = tf.keras.layers.BatchNormalization()(x10) #128*128*128
    
    x11 = tf.keras.layers.Conv2DTranspose(64, 2, strides = 2,
                                         padding='same', activation='relu')(x10)
    x11 = tf.keras.layers.BatchNormalization()(x11) #256*256*64
    x12 = tf.concat([x, x11], axis = -1) #256*256*128
    
    x12 = tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu')(x12)
    x12 = tf.keras.layers.BatchNormalization()(x12) 
    x12 = tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu')(x12)
    x12 = tf.keras.layers.BatchNormalization()(x12) #256*256*64
    
    output = tf.keras.layers.Conv2D(34, 1, padding='same', activation='softmax')(x12)
    #256*256*34
    return tf.keras.models.Model(inputs = inputs, outputs = output)

# %%
model = create_model()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 512)  2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1024) 4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  2097664     batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 512)  2048        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 32, 32, 1024 0           batch_normalization_7[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  4719104     tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 256)  1024        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_1 (TensorFlo [(None, 64, 64, 512) 0           batch_normalization_5[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  1179904     tf_op_layer_concat_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 128 512         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_2 (TensorFlo [(None, 128, 128, 25 0           batch_normalization_3[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 295040      tf_op_layer_concat_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 128 512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 128 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 256, 64) 256         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_3 (TensorFlo [(None, 256, 256, 12 0           batch_normalization_1[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 73792       tf_op_layer_concat_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256, 256, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256, 256, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 34) 2210        batch_normalization_21[0][0]
# ==================================================================================================
# Total params: 31,061,282
# Trainable params: 31,047,586
# Non-trainable params: 13,696
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model) # conda install pydot

# %%
#根据独热编码来封装
# tf.keras.metrics.MeanIoU(num_classes = 34)

# %%
#重新封装MeanIoU类，继承tf.keras.metrics.MeanIoU类
#编写__call__方法
class MeanIoU(tf.keras.metrics.MeanIoU):
    def __call__(self, y_true, y_pred, sample_weight = None):
        y_pred = tf.argmax(y_pred, axis = -1)
        return super().__call__(y_true, y_pred, sample_weight = sample_weight)

# %%
model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',
              metrics = ['acc', MeanIoU(num_classes = 34)])

# %%
EPOCHS = 2

# %%
dataset_train
# Out:
# <PrefetchDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.int32)>

# %%
dataset_test
# Out:
# <BatchDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.int32)>

# %%
history = model.fit(dataset_train,
                    epochs = EPOCHS,
                    steps_per_epoch = step_per_epoch,
                    validation_steps = val_step,
                    validation_data = dataset_test
                   )
# Out:
# Train for 1487 steps, validate for 250 steps
# Epoch 1/2
# 1487/1487 [==============================] - 1138s 765ms/step - loss: 1.0342 - acc: 0.7095 - mean_io_u: 0.1170 - val_loss: 1.2274 - val_acc: 0.6811 - val_mean_io_u: 0.1110
# Epoch 2/2
# 1487/1487 [==============================] - 1055s 709ms/step - loss: 0.8149 - acc: 0.7695 - mean_io_u: 0.1513 - val_loss: 1.0649 - val_acc: 0.7227 - val_mean_io_u: 0.1432

# %%
#与BatchSzie有关，因为现在一个Batch就两张图片，所以只能显示num=2张图片。
num = 2
for image, mask in dataset_train.take(1):
    pred_mask = model.predict(image)
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    
    plt.figure(figsize=(10, 10))
    for i in range(num):
        plt.subplot(num, 3, i*3+1)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(image[i]))
        plt.xlabel("image")
        plt.subplot(num, 3, i*3+2)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(mask[i]))
        plt.xlabel("mask")
        plt.subplot(num, 3, i*3+3)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(pred_mask[i]))
        plt.xlabel("pred_mask")

# %%
for image, mask in dataset_train.take(2):   
    plt.figure(figsize=(10, 10))
    plt.subplot(1, 1, 1)
    plt.imshow(tf.keras.preprocessing.image.array_to_img(image[0]))
